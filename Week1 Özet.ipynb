# %% [markdown]
# # 🧠 Yapay Zeka (Artificial Intelligence) ve Üretken Yapay Zeka (Generative AI) Özeti
#
# ---
#
# ## 📘 1. Yapay Zeka (Artificial Intelligence) Nedir?
#
# Yapay Zeka (YZ), **insan zekasına özgü süreçlerin makineler tarafından taklit edilmesi** anlamına gelir.
# Amaç, bilgisayarların düşünme, öğrenme, problem çözme, algılama ve karar verme gibi yetenekleri kazanmasıdır.
#
#
#
# ---
#
# ## ⚙️ 2. Temel Yapay Zeka Teknolojileri (Core AI Technologies)
#
# Yapay zekanın temeli, veriden öğrenen ve çevresini anlamlandırabilen teknolojilere dayanır.
# Bu teknolojiler, günümüzün akıllı sistemlerinin yapı taşlarını oluşturur.
#
# ### 🧩 Makine Öğrenimi (Machine Learning)
# Bilgisayarların açıkça programlanmadan **verilerden öğrenmesini** sağlayan yöntemdir.
# Geçmiş verilere bakarak örüntüler bulur ve geleceğe dair tahminler yapar.
#
# **Alt Türleri:**
# - **Denetimli Öğrenme (Supervised Learning):**
#
# Giriş ve çıkış verileri bellidir. Sistem, örneklerden öğrenerek yeni veriler için doğru tahminler yapar.
#
# Örnek: E-posta filtrelemede “spam” ya da “normal” ayrımı yapmak.
#
# - **Denetimsiz Öğrenme (Unsupervised Learning):**
#
# Etiketli veri yoktur; sistem verilerdeki gizli yapıları veya kümeleri keşfeder.
#
# Örnek: Müşteri segmentasyonu veya benzer ürünleri gruplama yani kümeleme.
#
# - **Pekiştirmeli Öğrenme (Reinforcement Learning):**
#
# Ödül-ceza mantığıyla deneme-yanılma yoluyla öğrenme.
#
# Örnek: otonom araçlar, oyun oynayan AI.
#
# ---
#
# ### 🧠 Derin Öğrenme (Deep Learning)
# **Çok katmanlı yapay sinir ağlarını** kullanarak karmaşık verileri işler.
# İnsan beynindeki nöron bağlantılarından esinlenmiştir.
#
# **Kullanım Alanları:**
# - Görüntü ve ses tanıma
# - Doğal dil işleme
# - Üretken yapay zeka sistemleri
#
# **Temel Mimariler:**
# - **CNNs:** Görsel veri işleme
# - **RNNs / LSTMs:** Zaman serisi ve dil işleme
# - **Transformers:** Büyük dil modellerinin temeli (örnek: GPT, BERT)
#
# ---
#
# ### 💬 Doğal Dil İşleme (Natural Language Processing - NLP)
# Makinelerin **insan dilini anlamasını, yorumlamasını ve üretmesini** sağlayan teknolojidir.
#
# **Uygulama Alanları:**
# - Çeviri sistemleri
# - Sohbet botları
# - Duygu analizi
# - Metin özetleme veya üretimi
#
# **Temel Modeller:**
# - Word2Vec, GloVe
# - BERT, GPT, T5, LLaMA
#
# ---
#
# ### 👁️ Bilgisayarlı Görü (Computer Vision)
# Makinelerin **görsel bilgiyi algılayıp anlamasını** sağlar.
# Amaç, insan gözünün algılama yeteneğini bilgisayarlara kazandırmaktır.
#
# **Uygulama Alanları:**
# - Otonom araçlar
# - Yüz tanıma sistemleri
# - Tıbbi görüntü analizi
# - Kalite kontrol ve nesne tanıma
#
# ---
#
# ## 🌈 3. Üretken Yapay Zeka (Generative AI) Nedir?
#
# Üretken Yapay Zeka, **yeni içerikler üretebilen bir yapay zeka alt dalıdır.**
# Bu içerikler metin, görsel, müzik, kod ve daha fazlası olabilir.
# Tüm bunlar, **eğitim verilerinden öğrenilen örüntülere** dayanır.
#
# **Temel Fark:**
# - **Klasik Yapay Zeka:** Veriyi analiz eder, sınıflandırır.
# - **Üretken Yapay Zeka:** Tamamen **yeni içerik** üretir.
#
# ---
#
# ## ⚙️ 4. Üretken Yapay Zeka Nasıl Çalışır?
#
# ### 🧱 Temel Modeller (Foundation Models)
# Farklı görevler için uyarlanabilen, çok büyük veri kümeleriyle eğitilmiş modellerdir.
#
# ### 🔬 Temel Teknolojiler:
# - **Transformers:** Modern dil modellerinin temel mimarisi
# - **GANs (Generative Adversarial Networks):** Görsel üretimi için kullanılan üretken ağlar
# - **Difüzyon Modelleri:** Görselleri adım adım iyileştirerek üretir (örnek: DALL·E, Midjourney)
# - **Büyük Dil Modelleri (LLMs):** İnsan benzeri metinler üretir (örnek: GPT, Claude, Gemini)
#
# ---
#
#
#
# ## 🎯 5. Genel Değerlendirme
#
# Yapay Zeka, yalnızca veriyi analiz eden bir teknoloji olmaktan çıkıp, **yaratıcı üretim yapan bir ekosistem** haline gelmiştir.
# Üretken Yapay Zeka (Generative AI), sanat, mühendislik, eğitim ve sağlık gibi alanlarda **insan yaratıcılığını güçlendiren** bir araçtır.
#
# Gelecekte, en başarılı sistemler;
# > **İnsan zekası + Yapay zekanın hesaplama gücü = Ortak üretkenlik (Augmented Intelligence)**
#
# Bu işbirliği, insanın potansiyelini artıran yeni bir teknolojik çağın kapısını açmaktadır.
#
# ---
#
# *Hazırlayan: Ayberk — Mekatronik Mühendisi*
# *Odak Alanları: Yapay Zeka • Derin Öğrenme • LLM • Makine Öğrenmesi • Veri Bilimi*
